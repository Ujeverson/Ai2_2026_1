# %%
import numpy as np

# %%
vet = np.array([1, 2, 3, 6, 8, 9, 10, 11, 13, 14,15,101, 15, 13, 12, 3, 1])
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1])

# %%
type(vet)
# Out:
# numpy.ndarray

# %%
vet2 = np.array([1, 2, 3, 4, 5])
vet2.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
print(vet[4])
# Out:
# 8

# %%
vet[0] = -1
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1])

# %%
vet = np.append(vet,202)
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1, 202, 202])

# %%
vet = vet[:-1]
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1, 202])

# %%
vet = np.delete(vet,-3)
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   1, 202])

# %%
vet.shape
# Out:
# (17,)

# %%
vetor = np.array([[0, -5],[11, 300]])
vetor
# Out:
# array([[  0,  -5],
#        [ 11, 300]])

# %%
vetor.shape
# Out:
# (2, 2)

# %%
vetor3x2 = np.array([[1,2],[3,4],[5,6]])
vetor3x2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor3x2.shape
# Out:
# (3, 2)

# %%
vetor2x3 = np.array([[1,2,3],[4,5,6]])
vetor2x3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
y = np.arange(2, 200, 5)
y
# Out:
# array([  2,   7,  12,  17,  22,  27,  32,  37,  42,  47,  52,  57,  62,
#         67,  72,  77,  82,  87,  92,  97, 102, 107, 112, 117, 122, 127,
#        132, 137, 142, 147, 152, 157, 162, 167, 172, 177, 182, 187, 192,
#        197])

# %%
unicos_vet = np.unique(vet)
unicos_vet
# Out:
# array([ -1,   1,   2,   3,   6,   8,   9,  10,  11,  12,  13,  14,  15,
#        101, 202])

# %%
idades = np.array([44, 45, 23, 23, 28, 19, 20, 19,17,51,29,28, 31,32])
mediaIA2 = round(idades.mean(),3)
x = mediaIA2
x
# Out:
# np.float64(29.214)

# %%
idades2 = np.array([44, 45, 23, 23, 28, 19, 20, 19,17,51,29,28, 31,32,31])
mediaIA2_1 = round(idades2.mean(),3)
y = mediaIA2_1
y
# Out:
# np.float64(29.333)

# %%
h = (x + 31)/2
h
# Out:
# np.float64(30.107)

# %%
j = np.unique(idades)
j
# Out:
# array([17, 19, 20, 23, 28, 29, 31, 32, 44, 45, 51])
